# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Step 1: Load dataset
df = pd.read_csv(r"G:\students.csv")
print("📄 Original Data:\n", df)
# Out:
# 📄 Original Data:
#        Name   Age  Gender Department  Marks  Attendance
# 0      Ali  21.0    Male        CSE   85.0        92.0
# 1     Sara  22.0  Female        EEE    NaN        88.0
# 2   Tanvir  23.0    Male        CSE   74.0        95.0
# 3   Nusrat  21.0  Female        BBA   90.0         NaN
# 4    Rakib   NaN    Male        CSE   65.0        70.0
# 5  Farzana  24.0  Female        EEE   78.0        82.0
# 6    Hasan  22.0    Male        BBA    NaN        85.0
# 7     Tuli  23.0  Female        CSE   88.0        90.0

# %%
# Step 2: Check for missing values
print("\n❓ Missing Values:\n", df.isnull().sum())
# Out:
# ❓ Missing Values:
#  Name          0
# Age           1
# Gender        0
# Department    0
# Marks         2
# Attendance    1
# dtype: int64

# %%
# Step 3: Handle missing values
df['Age'].fillna(df['Age'].mean(), inplace=True)
df['Marks'].fillna(df['Marks'].mean(), inplace=True)
df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)

print("\n✅ After Handling Missing Values:\n", df)
# Out:
# ✅ After Handling Missing Values:
#        Name        Age  Gender Department  Marks  Attendance
# 0      Ali  21.000000    Male        CSE   85.0        92.0
# 1     Sara  22.000000  Female        EEE   80.0        88.0
# 2   Tanvir  23.000000    Male        CSE   74.0        95.0
# 3   Nusrat  21.000000  Female        BBA   90.0        86.0
# 4    Rakib  22.285714    Male        CSE   65.0        70.0
# 5  Farzana  24.000000  Female        EEE   78.0        82.0
# 6    Hasan  22.000000    Male        BBA   80.0        85.0
# 7     Tuli  23.000000  Female        CSE   88.0        90.0
# C:\Users\USER\AppData\Local\Temp\ipykernel_9776\1621711505.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Age'].fillna(df['Age'].mean(), inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_9776\1621711505.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Marks'].fillna(df['Marks'].mean(), inplace=True)
# C:\Users\USER\AppData\Local\Temp\ipykernel_9776\1621711505.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Attendance'].fillna(df['Attendance'].mean(), inplace=True)

# %%
# Step 4: Basic statistics
print("\n📊 Summary Statistics:\n", df.describe())
# Out:
# 📊 Summary Statistics:
#               Age      Marks  Attendance
# count   8.000000   8.000000    8.000000
# mean   22.285714  80.000000   86.000000
# std     1.030158   8.053393    7.653197
# min    21.000000  65.000000   70.000000
# 25%    21.750000  77.000000   84.250000
# 50%    22.142857  80.000000   87.000000
# 75%    23.000000  85.750000   90.500000
# max    24.000000  90.000000   95.000000

# %%
# Step 5: Visualization

# Histogram of Marks
plt.figure(figsize=(6,4))
sns.histplot(df['Marks'], kde=True, color='skyblue')
plt.title("Distribution of Marks")
plt.xlabel("Marks")
plt.ylabel("Frequency")
plt.show()

# %%
# Average Marks by Department
plt.figure(figsize=(6,4))
sns.barplot(x='Department', y='Marks', data=df)
plt.title("Average Marks by Department")
plt.ylabel("Average Marks")
plt.show()

# %%
# Gender-wise Attendance
plt.figure(figsize=(6,4))
sns.boxplot(x='Gender', y='Attendance', data=df)
plt.title("Attendance by Gender")
plt.show()

# %%
# Step 6: Save Clean Data
df.to_csv("students_cleaned.csv", index=False)
print("✅ Cleaned data saved as 'students_cleaned.csv'")
# Out:
# ✅ Cleaned data saved as 'students_cleaned.csv'
